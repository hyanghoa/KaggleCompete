# %%
# %matplotlib inline

import numpy as np
import pydicom
import os
import matplotlib.pyplot as plt
from glob import glob
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import *
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data_path = "/Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/"#ID00007637202177411956430/"
output_path = working_path = "/Users/idongjun/KSA/output/"
g = glob(data_path + '/*')#.dcm')

# Print out the first 5 file names to verify we're in the right folder.
print ("Total of %d DICOM images.\nFirst 5 filenames:" % len(g))
print ('\n'.join(g[:5]))
# Out:
# Total of 176 DICOM images.
# First 5 filenames:
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00296637202279895784347
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00032637202181710233084
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00061637202188184085559
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00232637202260377586117
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00322637202284842245491

# %%
def load_scan(path):
    slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: int(x.InstanceNumber))
#     try:
#         slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
#     except:
#         slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
        
#     for s in slices:
#         s.SliceThickness = slice_thickness
        
    return slices

def get_pixels_hu(scans):
    image = np.stack([s.pixel_array for s in scans])
    # Convert to int16 (from sometimes int16), 
    # should be possible as values should always be low enough (<32k)
    image = image.astype(np.int16)

    # Set outside-of-scan pixels to 1
    # The intercept is usually -1024, so air is approximately 0
    image[image == -2000] = 0
    
    # Convert to Hounsfield units (HU)
    intercept = scans[0].RescaleIntercept
    slope = scans[0].RescaleSlope
    
    if slope != 1:
        image = slope * image.astype(np.float64)
        image = image.astype(np.int16)
        
    image += np.int16(intercept)
    
    return np.array(image, dtype=np.int16)

id=0
imgs=[]
for path in g:
    print(path, id)
    id += 1
    patient = load_scan(path)
    imgs.append(get_pixels_hu(patient))
# Out:
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00296637202279895784347 0
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00032637202181710233084 1
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00061637202188184085559 2
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00232637202260377586117 3
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00322637202284842245491 4
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00329637202285906759848 5
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00027637202179689871102 6
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00011637202177653955184 7
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00042637202184406822975 8
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00086637202203494931510 9
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00023637202179104603099 10
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00235637202261451839085 11
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00168637202237852027833 12
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00078637202199415319443 13
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00331637202286306023714 14
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00312637202282607344793 15
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00283637202278714365037 16
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00365637202296085035729 17
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00414637202310318891556 18
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00267637202270790561585 19
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00400637202305055099402 20
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00076637202199015035026 21
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00173637202238329754031 22
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00192637202245493238298 23
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00364637202296074419422 24
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00180637202240177410333 25
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00132637202222178761324 26
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00048637202185016727717 27
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00407637202308788732304 28
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00426637202313170790466 29
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00167637202237397919352 30
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00136637202224951350618 31
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00305637202281772703145 32
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00291637202279398396106 33
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00298637202280361773446 34
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00393637202302431697467 35
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00051637202185848464638 36
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00129637202219868188000 37
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00184637202242062969203 38
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00068637202190879923934 39
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00014637202177757139317 40
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00093637202205278167493 41
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00376637202297677828573 42
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00047637202184938901501 43
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00052637202186188008618 44
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00117637202212360228007 45
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00317637202283194142136 46
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00299637202280383305867 47
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00104637202208063407045 48
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00138637202231603868088 49
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00122637202216437668965 50
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00417637202310901214011 51
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00111637202210956877205 52
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00337637202286839091062 53
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00367637202296290303449 54
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00139637202231703564336 55
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00186637202242472088675 56
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00202637202249376026949 57
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00199637202248141386743 58
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00172637202238316925179 59
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00219637202258203123958 60
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00228637202259965313869 61
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00161637202235731948764 62
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00344637202287684217717 63
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00371637202296828615743 64
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00335637202286784464927 65
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00419637202311204720264 66
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00134637202223873059688 67
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00169637202238024117706 68
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00401637202305320178010 69
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00307637202282126172865 70
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00207637202252526380974 71
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00216637202257988213445 72
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00102637202206574119190 73
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00126637202218610655908 74
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00019637202178323708467 75
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00249637202266730854017 76
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00241637202264294508775 77
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00423637202312137826377 78
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00381637202299644114027 79
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00062637202188654068490 80
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00351637202289476567312 81
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00233637202260580149633 82
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00392637202302319160044 83
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00275637202271440119890 84
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00358637202295388077032 85
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00072637202198161894406 86
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00323637202285211956970 87
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00378637202298597306391 88
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00094637202205333947361 89
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00279637202272164826258 90
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00360637202295712204040 91
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00240637202264138860065 92
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00077637202199102000916 93
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00115637202211874187958 94
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00383637202300493233675 95
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00355637202295106567614 96
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00405637202308359492977 97
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00015637202177877247924 98
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00025637202179541264076 99
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00089637202204675567570 100
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00221637202258717315571 101
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00197637202246865691526 102
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00125637202218590429387 103
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00135637202224630271439 104
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00342637202287526592911 105
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00251637202267455595113 106
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00336637202286801879145 107
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00210637202257228694086 108
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00128637202219474716089 109
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00339637202287377736231 110
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00224637202259281193413 111
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00242637202264759739921 112
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00343637202287577133798 113
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00130637202220059448013 114
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00123637202217151272140 115
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00218637202258156844710 116
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00225637202259339837603 117
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00294637202279614924243 118
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00341637202287410878488 119
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00222637202259066229764 120
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00422637202311677017371 121
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00105637202208831864134 122
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00038637202182690843176 123
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00012637202177665765362 124
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00264637202270643353440 125
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00149637202232704462834 126
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00026637202179561894768 127
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00060637202187965290703 128
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00229637202260254240583 129
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00140637202231728595149 130
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00007637202177411956430 131
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00020637202178344345685 132
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00370637202296737666151 133
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00309637202282195513787 134
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00248637202266698862378 135
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00131637202220424084844 136
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00288637202279148973731 137
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00368637202296470751086 138
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00109637202210454292264 139
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00290637202279304677843 140
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00010637202177584971671 141
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00183637202241995351650 142
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00035637202182204917484 143
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00234637202261078001846 144
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00082637202201836229724 145
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00213637202257692916109 146
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00127637202219096738943 147
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00273637202271319294586 148
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00099637202206203080121 149
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00411637202309374271828 150
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00398637202303897337979 151
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00421637202311550012437 152
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00190637202244450116191 153
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00276637202271694539978 154
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00110637202210673668310 155
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00255637202267923028520 156
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00075637202198610425520 157
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00340637202287399835821 158
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00133637202223847701934 159
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00090637202204766623410 160
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00408637202308839708961 161
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00073637202198167792918 162
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00030637202181211009029 163
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00388637202301028491611 164
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00124637202217596410344 165
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00165637202237320314458 166
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00119637202215426335765 167
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00170637202238079193844 168
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00319637202283897208687 169
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00196637202246668775836 170
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00285637202278913507108 171
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00067637202189903532242 172
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00214637202257820847190 173
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00009637202177434476278 174
# /Users/idongjun/KSA/osic-pulmonary-fibrosis-progression/train/ID00108637202209619669361 175

# %%
print(imgs[0].shape)
# Out:
# (31, 512, 512)

# %%
for id in range(0, len(imgs)):
    np.save(output_path + "fullimages_%d.npy" % (id), imgs[id])

# %%
file_used=output_path+"fullimages_%d.npy" % id
imgs_to_process = np.load(file_used).astype(np.float64) 

plt.hist(imgs_to_process.flatten(), bins=50, color='c')
plt.tick_params(labelcolor='w')
plt.xlabel("Hounsfield Units (HU)", c='w')
plt.ylabel("Frequency", c='w')
plt.show()

# %%
imgs_to_process = np.load(output_path+'fullimages_{}.npy'.format(id))

def sample_stack(stack, rows=3, cols=3, start_with=5, show_every=3):
    fig, ax = plt.subplots(rows,cols,figsize=[12,12])
    for i in range(rows*cols):
        ind = start_with + i*show_every
        ax[int(i/rows),int(i % rows)].set_title('slice %d' % ind)
        ax[int(i/rows),int(i % rows)].imshow(stack[ind], cmap='gray')
        ax[int(i/rows),int(i % rows)].axis('off')
    plt.show()

sample_stack(imgs_to_process)

# %%
print ("Slice Thickness: %f" % patient[0].SliceThickness)
print ("Pixel Spacing (row, col): (%f, %f) " % (patient[0].PixelSpacing[0], patient[0].PixelSpacing[1]))
# Out:
# Slice Thickness: 0.625000
# Pixel Spacing (row, col): (0.468750, 0.468750)

# %%
imgs_to_process = np.load(output_path+'fullimages_{}.npy'.format(id))

def resample(image, scan, new_spacing=[1,1,1]):
    # Determine current pixel spacing
    spacing = map(float, ([scan[0].SliceThickness] + list(scan[0].PixelSpacing)))
    spacing = np.array(list(spacing))

    resize_factor = spacing / new_spacing
    new_real_shape = image.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize_factor = new_shape / image.shape
    new_spacing = spacing / real_resize_factor
    
    image = scipy.ndimage.interpolation.zoom(image, real_resize_factor)
    
    return image, new_spacing

print ("Shape before resampling\t", imgs_to_process.shape)
imgs_after_resamp, spacing = resample(imgs_to_process, patient, [1,1,1])
print ("Shape after resampling\t", imgs_after_resamp.shape)
# Out:
# Shape before resampling	 (512, 768, 768)
# Shape after resampling	 (320, 360, 360)

# %%
def make_mesh(image, threshold=-300, step_size=1):

    print ("Transposing surface")
    p = image.transpose(2,1,0)
    
    print ("Calculating surface")
    verts, faces, norm, val = measure.marching_cubes(p, threshold, step_size=step_size, allow_degenerate=True) 
    return verts, faces

def plotly_3d(verts, faces):
    x,y,z = zip(*verts) 
    
    print ("Drawing")
    
    # Make the colormap single color since the axes are positional not intensity. 
#    colormap=['rgb(255,105,180)','rgb(255,255,51)','rgb(0,191,255)']
    colormap=['rgb(236, 236, 212)','rgb(236, 236, 212)']
    
    fig = FF.create_trisurf(x=x,
                        y=y, 
                        z=z, 
                        plot_edges=False,
                        colormap=colormap,
                        simplices=faces,
                        backgroundcolor='rgb(64, 64, 64)',
                        title="Interactive Visualization")
    iplot(fig)

def plt_3d(verts, faces):
    print ("Drawing")
    x,y,z = zip(*verts) 
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh = Poly3DCollection(verts[faces], linewidths=0.05, alpha=1)
    face_color = [1, 1, 0.9]
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)

    ax.set_xlim(0, max(x))
    ax.set_ylim(0, max(y))
    ax.set_zlim(0, max(z))
    ax.set_facecolor((0.7, 0.7, 0.7))
    plt.show()

# %%
v, f = make_mesh(imgs_after_resamp, 350)
plt_3d(v, f)

# %%
v, f = make_mesh(imgs_after_resamp, 350, 2)
plotly_3d(v, f)

# %%
#Standardize the pixel values
def make_lungmask(img, display=False):
    row_size= img.shape[0]
    col_size = img.shape[1]
    
    mean = np.mean(img)
    std = np.std(img)
    img = img-mean
    img = img/std
    # Find the average pixel value near the lungs
    # to renormalize washed out images
    middle = img[int(col_size/5):int(col_size/5*4),int(row_size/5):int(row_size/5*4)] 
    mean = np.mean(middle)  
    max = np.max(img)
    min = np.min(img)
    # To improve threshold finding, I'm moving the 
    # underflow and overflow on the pixel spectrum
    img[img==max]=mean
    img[img==min]=mean
    #
    # Using Kmeans to separate foreground (soft tissue / bone) and background (lung/air)
    #
    kmeans = KMeans(n_clusters=2).fit(np.reshape(middle,[np.prod(middle.shape),1]))
    centers = sorted(kmeans.cluster_centers_.flatten())
    threshold = np.mean(centers)
    thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image

    # First erode away the finer elements, then dilate to include some of the pixels surrounding the lung.  
    # We don't want to accidentally clip the lung.

    eroded = morphology.erosion(thresh_img,np.ones([3,3]))
    dilation = morphology.dilation(eroded,np.ones([8,8]))

    labels = measure.label(dilation) # Different labels are displayed in different colors
    label_vals = np.unique(labels)
    regions = measure.regionprops(labels)
    good_labels = []
    for prop in regions:
        B = prop.bbox
        if B[2]-B[0]<row_size/10*9 and B[3]-B[1]<col_size/10*9 and B[0]>row_size/5 and B[2]<col_size/5*4:
            good_labels.append(prop.label)
    mask = np.ndarray([row_size,col_size],dtype=np.int8)
    mask[:] = 0

    #
    #  After just the lungs are left, we do another large dilation
    #  in order to fill in and out the lung mask 
    #
    for N in good_labels:
        mask = mask + np.where(labels==N,1,0)
    mask = morphology.dilation(mask,np.ones([10,10])) # one last dilation

    if (display):
        fig, ax = plt.subplots(3, 2, figsize=[12, 12])
        ax[0, 0].set_title("Original")
        ax[0, 0].imshow(img, cmap='gray')
        ax[0, 0].axis('off')
        ax[0, 1].set_title("Threshold")
        ax[0, 1].imshow(thresh_img, cmap='gray')
        ax[0, 1].axis('off')
        ax[1, 0].set_title("After Erosion and Dilation")
        ax[1, 0].imshow(dilation, cmap='gray')
        ax[1, 0].axis('off')
        ax[1, 1].set_title("Color Labels")
        ax[1, 1].imshow(labels)
        ax[1, 1].axis('off')
        ax[2, 0].set_title("Final Mask")
        ax[2, 0].imshow(mask, cmap='gray')
        ax[2, 0].axis('off')
        ax[2, 1].set_title("Apply Mask on Original")
        ax[2, 1].imshow(mask*img, cmap='gray')
        ax[2, 1].axis('off')
        
        plt.show()
    return mask*img

# %%
img = imgs_after_resamp[260]
make_lungmask(img, display=True)

# %%
masked_lung = []

for img in imgs_after_resamp:
    masked_lung.append(make_lungmask(img))

sample_stack(masked_lung, show_every=10)

# %%
np.save(output_path + "maskedimages_%d.npy" % (id), imgs)
